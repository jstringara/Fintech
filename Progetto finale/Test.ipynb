# %%
#importa InvestmentReplica.csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

df = pd.read_csv("InvestmentReplica.csv")
df.head()
# Out:
#          Date     MXWO    MXWD  LEGATRUU   HFRXGL     RX1      TY1    GC1  \
# 0  23/10/2007  1633.44  414.14   350.214  1343.63  113.70  110.516  759.0
# 1  30/10/2007  1663.89  423.26   352.541  1356.53  113.79  110.656  787.8
# 2  06/11/2007  1651.59  419.51   354.176  1360.20  113.79  110.875  823.4
# 3  13/11/2007  1601.81  405.98   357.222  1347.16  114.35  111.719  799.0
# 4  20/11/2007  1570.74  398.54   359.445  1335.21  114.72  113.156  791.4
#
#      CO1      ES1     VG1      NQ1    LLL1     TP1      DU1      TU2
# 0  82.85  1525.50  4393.0  2212.00  1287.0  1570.5  103.385  103.719
# 1  87.44  1536.00  4476.0  2217.75  1323.9  1610.5  103.410  103.813
# 2  93.26  1525.00  4425.0  2233.50  1320.0  1575.5  103.410  104.047
# 3  88.83  1483.25  4323.0  2066.75  1271.0  1440.5  103.595  104.305
# 4  95.49  1446.00  4296.0  2035.50  1225.2  1472.5  103.800  104.945

# %%
#plot the mxwo index in time
df.plot(x='Date', y='MXWO', figsize=(15, 6))
plt.xlabel('Date')
plt.ylabel('MXWO Index')
plt.title('MXWO Index in time')
plt.show()
